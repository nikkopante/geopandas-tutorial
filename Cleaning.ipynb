# %%
import pandas as pd
import numpy as np

# %%
filename = "other-data/DOH COVID Data Drop_ 20201031 - 04 Case Information.csv"
df = pd.read_csv(filename)
df.head()
# Out:
# /home/nikko/anaconda3/envs/geo_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   CaseCode   Age  AgeGroup     Sex DateSpecimen DateResultRelease DateRepConf  \
# 0  C642447  25.0  25 to 29    MALE   2020-07-14        2020-07-15  2020-07-19
# 1  C919481  54.0  50 to 54    MALE   2020-07-27        2020-07-30  2020-08-03
# 2  C378726  50.0  50 to 54  FEMALE   2020-07-18        2020-07-19  2020-07-24
# 3  C556553  30.0  30 to 34  FEMALE   2020-05-27        2020-05-27  2020-05-31
# 4  C210854  33.0  30 to 34    MALE   2020-07-21        2020-07-24  2020-07-28
#
#   DateDied DateRecover RemovalType  ...                         ProvRes  \
# 0      NaN         NaN   RECOVERED  ...  COTABATO CITY (NOT A PROVINCE)
# 1      NaN         NaN   RECOVERED  ...                             NaN
# ...

# %%
df.isna().sum()
# Out:
# CaseCode                  0
# Age                    2183
# AgeGroup               2183
# Sex                       0
# DateSpecimen          62088
# DateResultRelease     61320
# DateRepConf               0
# DateDied             373574
# DateRecover          288736
# RemovalType           42462
# Admitted                150
# RegionRes              3673
# ProvRes               24931
# CityMunRes            35454
# CityMuniPSGC          35454
# BarangayRes          229356
# BarangayPSGC         229356
# HealthStatus              0
# Quarantined             154
# DateOnset            256238
# Pregnanttab          208719
# ValidationStatus     128901
# dtype: int64
